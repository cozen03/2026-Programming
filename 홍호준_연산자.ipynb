# %% [markdown]
# <a href="https://colab.research.google.com/github/cozen03/2026-Programming/blob/main/%ED%99%8D%ED%98%B8%EC%A4%80_%EC%97%B0%EC%82%B0%EC%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 프로그래밍  3. 연산자
# 연산: 프로그래밍에서 값을 처리하기 위해 수행하는 작업
#
# 연산자: 특정 연산을 위해 사용되는 기호
#
# 대정고등학교 창의정보부 - 파이썬 연산자 연습문제입니다. 배운 내용을 바탕으로 아래의 코드를 완성해 보세요.

# %%
#산술연산자

print(7+4)
print(7-4)
print(7*4) #곱하기
print(7**4) #거듭제곱
print(7/4) #나누기
print(7//4) #나눗셈의 정수의 몫
print(7%4) #나눗셈의 나머지
# Out:
# 11
# 3
# 28
# 2401
# 1.75
# 1
# 3
# 0.1111111111111111

# %%
#비교연산자

print(5<6) #작다
print(5>6) #크다
print(7<=7) #작거나 같다
print(7>=7) #크거나 같다
print(7==7) #같다
print(7!=7) #같지 않다
# Out:
# True
# False
# True
# True
# True
# False

# %%
#논리 연산자

print(True and False) #논리곱
print(True or False) #논리합
print(not False) #논리 부정

# %%
#대입 연산자

a=0 #대입
print(a)
a+=5 #덧셈 연산 결과 대입
print(a)
a-=3 #뺄셈 연산 결과 대입
print(a)
a*=4 #곱셈 연산 결과 대입
print(a)
a**=2 #거듭제곱 연산 결과 대입
print(a)
a/=4 #나눗셈 연산 결과 대입
print(a)
a//=3 #나눗셈 몫 연산 결과 대입
print(a)
a%=3 #나머지 연산 결과 대입
print(a)
# Out:
# 0
# 5
# 2
# 8
# 64
# 16.0
# 5.0
# 2.0

# %%
#비트 연산자

print(0b1100&0b1010) #비트 논리곱(AND)
print(0b1100|0b1010) #비트 논리합(OR)
print(0b1100^0b1010) #비트 배타적 논리합(XOR)
print(~0b1010) #비트 논리 부정(NOT)
print(0b1100<<2) #비트 왼쪽 시프트
print(0b1100>>1) #비트 오른쪽 시프트
# Out:
# 8
# 14
# 6
# -11
# 48
# 6

# %% [markdown]
# ## 1. 산술 연산자 활용하기
# **문제:** 사용자로부터 초 단위로 시간을 입력받아, 몇 분 몇 초인지 계산하여 출력하는 프로그램을 완성해 보세요.

# %%
sec = int(input('시간을 초 단위로 입력하세요: '))

# 아래에 알맞은 산술 연산자를 사용하여 코드를 완성하세요.
minutes = sec//60 # 빈칸을 채우세요
seconds = sec%60 # 빈칸을 채우세요

print(f'{minutes}분 {seconds}초')
# Out:
# 시간을 초 단위로 입력하세요: 1234
# 20분 34초

# %% [markdown]
# ## 2. 비교 연산자와 논리 연산자
# **문제:** 미리 저장된 아이디(`user123`)와 패스워드(`password456`)가 있습니다. 사용자로부터 아이디와 패스워드를 입력받아, 두 정보가 **모두** 일치하는지(`True` 또는 `False`) 확인하는 프로그램을 완성해 보세요.

# %%
saved_id = 'user123'
saved_pw = 'password456'

userid = input('아이디를 입력하세요: ')
password = input('패스워드를 입력하세요: ')

# 비교 연산자(==)와 논리 연산자(and, or, not 중 하나)를 조합하여 완성하세요.
is_match = (userid == saved_id) and (password == saved_pw)  # 빈칸을 채우세요  (password == saved_pw)

print('id, pw 모두 일치 여부:', is_match)
# Out:
# 아이디를 입력하세요: user123
# 패스워드를 입력하세요: password456
# id, pw 모두 일치 여부: True

# %% [markdown]
# ## 3. 대입 연산자를 활용한 현금 자동 입출금기(ATM)
# **문제:** 출금할 금액을 입력하면 50,000원, 10,000원, 5,000원, 1,000원 지폐가 최소 몇 장 필요한지 계산하는 프로그램입니다. 복합 대입 연산자(`%=`)를 활용하여 코드를 완성해 보세요.

# %%
amount = int(input('출금할 금액을 입력하세요: '))

print(f'50,000원: {amount // 50000}장')
amount %= 50000  # 5만원권을 빼고 남은 금액을 다시 amount에 대입

print(f'10,000원: {amount // 10000}장')
# 알맞은 복합 대입 연산자를 작성하세요.
amount %= 10000

print(f'5,000원: {amount // 5000}장')
# 알맞은 복합 대입 연산자를 작성하세요.
amount %= 5000

print(f'1,000원: {amount // 1000}장')
# Out:
# 출금할 금액을 입력하세요: 150000
# 50,000원: 3장
# 10,000원: 0장
# 5,000원: 0장
# 1,000원: 0장

# %% [markdown]
# ## 4. 비트 연산자 확인
# **문제:** 비트 시프트 연산자를 사용하여 정수 `4`에 대해 빠른 곱셈과 나눗셈을 수행해 보세요.

# %%
value = 4

# 왼쪽으로 1비트 시프트 (곱하기 2의 효과)
result_left = value # 빈칸을 채우세요
print(f'{value} 왼쪽 1비트 시프트 결과: {result_left}')

# 오른쪽으로 1비트 시프트 (나누기 2의 효과)
result_right = value # 빈칸을 채우세요
print(f'{value} 오른쪽 1비트 시프트 결과: {result_right}')
# Out:
# 4 왼쪽 1비트 시프트 결과: 4
# 4 오른쪽 1비트 시프트 결과: 4

# %% [markdown]
# #복리 이자 계산 프로그램 만들어보기

# %% [markdown]
# <img src="https://drive.google.com/thumbnail?id=16JXS48VTy3uKNqNpDFjSfv4nh9n7uvrj&sz=w1000" width ="2000" align ='right'>

# %% [markdown]
# ### 💡 1. 해결해야 할 문제를 기록해 보자.
#
# > **답변:** [이곳을 더블클릭하여 본인의 답변을 작성하고 Shift + Enter를 누르세요]

# %% [markdown]
# ### 📝 2. 문제 해결에 필요한 핵심 기능을 기록해 보자.
#
# > **예:** 입출력 함수, 산술 연산자 등
# >
# > **나의 답변:** [이곳을 더블클릭하여 핵심 기능을 기록하고 Shift + Enter를 누르세요]
#
# ---
#
# ### 💻 3. 위의 문제를 해결하는 프로그램을 완성해 보자.
#
# *(아래 코드 셀에 배운 연산자를 활용하여 프로그램을 직접 작성하고 실행해 보세요!)*

# %%
#여기에 프로그램을 작성합니다.
