# %% [markdown]
# <a href="https://colab.research.google.com/github/cozen03/2026-Programming/blob/main/%ED%99%8D%ED%98%B8%EC%A4%80_%EB%8B%A8%EC%96%B4%EC%B1%84%EC%9A%B0%EA%B8%B0_%EA%B2%8C%EC%9E%84%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("오늘은 수요일")
# Out:
# 오늘은 수요일

# %%
firstName = "홍호준"
print('안녕하세요','저는',firstName+'이며 프로그래머랍니다!')
# Out:
# 안녕하세요 저는 홍호준이며 프로그래머랍니다!

# %%
firstName = 15
print(firstName)
# Out:
# 15

# %%
'''
변수규칙
1. 변수 이름은 알파벳과 숫자(한글도 가능)로 구성
2. 변수 이름은 숫자로 시작하면 안됨
3. 변수 이름에는 공백이 들어가면 안됨
4. 변수 이름은 대소 문자로 구분
'''
a = 10
A = 10

a = 20

print(a, A)
# Out:
# 20 10

# %%
firstName = '쉬무엘'
lastName = '포터'
fullName = firstName+" "+lastName

print("안녕하세요, 저는",fullName,"이며 프로그래머랍니다!")
# Out:
# 안녕하세요, 저는 쉬무엘 포터 이며 프로그래머랍니다!

# %%
name = input("이름을 입력히세요.: ")
print("안녕하세요",name,"님. 만나서 반갑습니다!")
# Out:
# 이름을 입력히세요.: 홍호준
# 안녕하세요 홍호준 님. 만나서 반갑습니다!

# %%
animal = input("애완동물을 입력해
주세요: ")
name = input("애완동물의 이름을 입력해주세요: ")
adjective1 = input("애완동물의 특징을 입력해주세요: ")
adjective2 = input("또 다른 특징을 입력해주세요: ")
color1 = input("애완동물의 색깔을 입력해주세요: ")
noun1 = input("애완동물이 먹는 음식을 입력해 주세요: ")
noun2 = input("또 다른 먹는 음식을 입력해 주세요: ")
noun3 = input("또 다른 먹는 음식을 입력해 주세요: ")
noun4 = input("애완동물이 좋아하는 장난감을 입력해 주세요: ")
adjective3 = input("애완동물이 좋아하는 장난감의 특징 입력해 주세요: ")
color2 = input("애완동물이 좋아하는 장난감의 색깔을 입력해 주세요: ")
print("저의 반려동물은", animal, "이며 이름은", name, "입니다.")
print(adjective1, "(이)고", color1, "이며", adjective2, "니다.")
print(name, "은(는) ",  noun1, ",", noun2, ",", noun3, "을(를) 먹습니다.")
print("가장 좋아하는 장난감은", adjective3, color2, noun4, "입니다.")
# Out:
# 애완동물을 입력해주세요: 골든 리트리버
# 애완동물의 이름을 입력해주세요: 라떼
# 애완동물의 특징을 입력해주세요: 포근함
# 또 다른 특징을 입력해주세요: 귀여움
# 애완동물의 색깔을 입력해주세요: 노란색
# 애완동물이 먹는 음식을 입력해 주세요: 사료
# 또 다른 먹는 음식을 입력해 주세요: 닭뼈
# 또 다른 먹는 음식을 입력해 주세요: 고기
# 애완동물이 좋아하는 장난감을 입력해 주세요: 인형
# 애완동물이 좋아하는 장난감의 특징 입력해 주세요: 강아지 모양
# 애완동물이 좋아하는 장난감의 색깔을 입력해 주세요: 갈색
# 저의 반려동물은 골든 리트리버 이며 이름은 라떼 입니다.
# 포근함 (이)고 노란색 이며 귀여움 니다.
# 라떼 은(는)  사료 , 닭뼈 , 고기 을(를) 먹습니다.
# 가장 좋아하는 장난감은 강아지 모양 갈색 인형 입니다.
